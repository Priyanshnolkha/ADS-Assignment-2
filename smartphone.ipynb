# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
p=pd.read_csv(r"/content/smartphones.csv")
p.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
p.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
p.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
p.describe(include="all")
# Out:
#                          model    price      rating  \
# count                     1020     1020  879.000000
# unique                    1020      412         NaN
# top     Samsung Galaxy M52s 5G  ₹14,999         NaN
# freq                         1       21         NaN
# mean                       NaN      NaN   78.258248
# std                        NaN      NaN    7.402854
# min                        NaN      NaN   60.000000
# 25%                        NaN      NaN   74.000000
# 50%                        NaN      NaN   80.000000
# 75%                        NaN      NaN   84.000000
# max                        NaN      NaN   89.000000
#
#                                    sim  \
# count                             1020
# unique                              28
# top     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# freq                               324
# mean                               NaN
# std                                NaN
# min                                NaN
# ...

# %%
p.isnull().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
p['rating'].unique()
# Out:
# array([89., 81., 75., 82., 80., 86., 85., 84., 79., nan, 65., 72., 76.,
#        87., 88., 83., 73., 64., 68., 74., 78., 62., 66., 69., 67., 71.,
#        77., 61., 60., 63., 70.])

# %%
r=p['rating'].dropna()
r
# Out:
# 0       89.0
# 1       81.0
# 2       75.0
# 3       81.0
# 4       82.0
#         ...
# 1015    83.0
# 1016    75.0
# 1017    85.0
# 1018    80.0
# 1019    74.0
# Name: rating, Length: 879, dtype: float64

# %%
r.isnull().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
sns.boxplot(r)
plt.title("rating graph")
plt.show()

# %%
p['rating']=p['rating'].fillna(p['rating'].mean())

# %%
p.isnull().sum()
# Out:
# model         0
# price         0
# rating        0
# sim           0
# processor     0
# ram           0
# battery       0
# display       0
# camera        1
# card          7
# os           17
# dtype: int64

# %%
r=p['os'].dropna()
r
# Out:
# 0       Android v13
# 1       Android v12
# 2       Android v13
# 3       Android v12
# 4       Android v13
#            ...
# 1015    No FM Radio
# 1016    Android v11
# 1017    Android v12
# 1018    Android v12
# 1019    Android v12
# Name: os, Length: 1003, dtype: object

# %%
r.isnull().sum()
# Out:
# np.int64(0)

# %%
p['os'] = p['os'].fillna("Unknown")

# %%
p.isnull().sum()
# Out:
# model        0
# price        0
# rating       0
# sim          0
# processor    0
# ram          0
# battery      0
# display      0
# camera       1
# card         7
# os           0
# dtype: int64

# %%
r=p['camera'].dropna()
r
# Out:
# 0       50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1       64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2       50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3       50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4       108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#                               ...
# 1015    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018    108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019    64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# Name: camera, Length: 1019, dtype: object

# %%
r.isnull().sum()
# Out:
# np.int64(0)

# %%
p['camera'] = p['camera'].fillna("Unknown")

# %%
r=p['card'].dropna()
r
# Out:
# 0              Memory Card Not Supported
# 1        Memory Card (Hybrid), upto 1 TB
# 2       Memory Card Supported, upto 1 TB
# 3        Memory Card (Hybrid), upto 1 TB
# 4              Memory Card Not Supported
#                       ...
# 1015                         Android v12
# 1016    Memory Card Supported, upto 1 TB
# 1017           Memory Card Not Supported
# 1018    Memory Card Supported, upto 1 TB
# 1019    Memory Card Supported, upto 1 TB
# Name: card, Length: 1013, dtype: object

# %%
r.isnull().sum()
# Out:
# np.int64(0)

# %%
p['card'] = p['card'].fillna("Unknown")

# %%
p.to_csv("cleaned_smartphone.csv", index=False)
